# %%
# Setup

import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

# %%
# Read county cancer data

cancer_stats_df = pd.read_csv('Project_1, cancer_export_df.csv')

cancer_stats_df.head(20)
# Out:
#                  County          State  \
# 0    Los Angeles County     California
# 1           Cook County       Illinois
# 2       Maricopa County        Arizona
# 3         Harris County          Texas
# 4      San Diego County     California
# 5         Orange County     California
# 6     Miami-Dade County        Florida
# 7          Kings County       New York
# 8         Queens County       New York
# 9        Broward County        Florida
# 10         Wayne County       Michigan
# 11     Riverside County     California
# 12          King County     Washington
# 13       Suffolk County       New York
# 14        Dallas County          Texas
# 15    Palm Beach County        Florida
# 16        Nassau County       New York
# 17         Clark County         Nevada
# 18      New York County       New York
# 19  Philadelphia County   Pennsylvania
#
#    Age-Adjusted Incidence Rate - cases per 100,000 Average Annual Count  \
# 0                                            380.3                39939
# 1                                            448.9                25748
# 2                                            394.2                17933
# 3                                            395.1                15735
# 4                                            417.7                14412
# 5                                            407.5                14072
# 6                                            423.1                13536
# 7                                            445.7                12044
# 8                                            423.5                11239
# 9                                              449                10313
# 10                                           503.1                10298
# 11                                           402.8                10046
# 12                                           446.8                 9969
# 13                                           536.1                 9819
# 14                                           421.1                 9700
# 15                                           442.9                 9678
# 16                                           509.9                 8862
# 17                                           386.4                 8804
# 18                                           454.8                 8623
# 19                                           500.8                 8258
#
#    Recent Trend
# 0       falling
# 1       falling
# 2       falling
# 3       falling
# 4       falling
# 5       falling
# 6       falling
# 7       falling
# 8       falling
# 9       falling
# 10      falling
# 11      falling
# 12      falling
# 13      falling
# 14       stable
# 15       stable
# 16      falling
# 17       stable
# 18      falling
# 19      falling

# %%
# Create Bar chart showing cancer rate by state

plt.bar
