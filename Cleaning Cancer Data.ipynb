# %%
# Setup 

import pandas as pd
import numpy as np

# %%
# Storing Path

cancer_data = "Resources/County_Cancer_Data.csv"

# %%
# Reading in the data

county_cancer_df = pd.read_csv(cancer_data)
county_cancer_df.head()
# Out:
#                                  State  Unnamed: 1     FIPS  \
# 0  Los Angeles County, California(7,8)         NaN   6037.0
# 1           Cook County, Illinois(6,8)         NaN  17031.0
# 2        Maricopa County, Arizona(6,8)         NaN   4013.0
# 3            Harris County, Texas(6,8)         NaN  48201.0
# 4                    Puerto Rico(6,10)         NaN  72001.0
#
#   Age-Adjusted Incidence Rate(†) - cases per 100,000  \
# 0                                              380.3
# 1                                              448.9
# 2                                              394.2
# 3                                              395.1
# 4                                              355.4
#
#   Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                         378.6                           382
# 1                         446.4                         451.4
# 2                         391.6                         396.8
# 3                         392.2                         397.9
# 4                         352.9                           358
#
#   Average Annual Count Recent Trend  \
# 0                39939      falling
# 1                25748      falling
# 2                17933      falling
# 3                15735      falling
# 4                15726       stable
#
#   Recent 5-Year Trend (‡) in Incidence Rates Lower 95% Confidence Interval.1  \
# 0                                       -1.9                            -2.3
# 1                                       -1.4                            -1.8
# 2                                       -1.3                            -1.7
# 3                                       -2.7                            -3.2
# 4                                       -2.4                              -7
#
#   Upper 95% Confidence Interval.1
# 0                            -1.4
# 1                            -1.1
# 2                              -1
# 3                            -2.1
# 4                             2.5

# %%
# Split out county and stae into separate columns

county_cancer_df =

# %%
# Remove unnecessary columns from the dataframe

reduced_county_cancer_df = county_cancer_df[["State","Age-Adjusted Incidence Rate(†) - cases per 100,000","Average Annual Count","Recent Trend", ]]
reduced_county_cancer_df.head()
# Out:
#                                  State  \
# 0  Los Angeles County, California(7,8)
# 1           Cook County, Illinois(6,8)
# 2        Maricopa County, Arizona(6,8)
# 3            Harris County, Texas(6,8)
# 4                    Puerto Rico(6,10)
#
#   Age-Adjusted Incidence Rate(†) - cases per 100,000 Average Annual Count  \
# 0                                              380.3                39939
# 1                                              448.9                25748
# 2                                              394.2                17933
# 3                                              395.1                15735
# 4                                              355.4                15726
#
#   Recent Trend
# 0      falling
# 1      falling
# 2      falling
# 3      falling
# 4       stable

# %%
#
