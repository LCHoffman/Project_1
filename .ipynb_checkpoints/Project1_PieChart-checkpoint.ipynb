# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
from api_key import g_map_key
import gmaps

# Import csv files for all GA State cancer files

csv_kidney = "GeorgiaData_Kidney.csv"
kidney_df = pd.read_csv(csv_kidney)

csv_leukemia = "GeorgiaData_Leukemia.csv"
leukimia_df = pd.read_csv(csv_leukemia)

csv_liver = "GeorgiaData_Liver.csv"
liver_df = pd.read_csv(csv_liver)

csv_lung = "GeorgiaData_Lung & Bronchus.csv"
lung_df = pd.read_csv(csv_lung)

csv_nonhodgkin = "GeorgiaData_NonHodgkinLymphoma.csv"
nonhodgkin_df = pd.read_csv(csv_nonhodgkin)

# %%
# Append dataframe and merge all dataframes

ga_cancer_df = leukimia_df.append(kidney_df)
ga_cancer_df = liver_df.append(ga_cancer_df)
ga_cancer_df = lung_df.append(ga_cancer_df)
ga_cancer_df = nonhodgkin_df.append(ga_cancer_df)
ga_cancer_df
# Out:
#         County   FIPS Age-Adjusted Incidence Rate(â€ ) - cases per 100,000  \
# 0      Georgia  13000                                               18.2
# 1           US      0                                               19.3
# 2       Gilmer  13123                                               29.3
# 3        Towns  13281                                               29.2
# 4      Pickens  13227                                               27.4
# ..         ...    ...                                                ...
# 156    Webster  13307                                                NaN
# 157    Wheeler  13309                                                NaN
# 158     Wilcox  13315                                                NaN
# 159     Wilkes  13317                                                NaN
# 160  Wilkinson  13319                                                NaN
#
#     Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                            17.8                          18.6
# 1                            19.2                          19.3
# 2                            22.1                          38.2
# 3                            15.6                          49.9
# 4                            20.4                          36.1
# ..                            ...                           ...
# 156                             *                             *
# 157                             *                             *
# 158                             *                             *
# 159                             *                             *
# 160                             *                             *
#
#     Average Annual Count Recent Trend  \
# 0                1911.00       stable
# 1               70661.00      falling
# 2                  13.00       rising
# 3                   5.00            *
# 4                  12.00       stable
# ..                   ...          ...
# 156           3 or fewer            *
# 157           3 or fewer            *
# 158           3 or fewer            *
# 159           3 or fewer            *
# 160           3 or fewer            *
#
#     Recent 5-Year Trend (â€¡) in Incidence Rates  \
# 0                                            0.3
# 1                                           -1.5
# 2                                           15.6
# 3                                              *
# 4                                            2.4
# ..                                           ...
# 156                                            *
# 157                                            *
# 158                                            *
# 159                                            *
# 160                                            *
#
#     Lower 95% Confidence Interval.1 Upper 95% Confidence Interval.1  \
# 0                              -0.1                             0.7
# 1                              -2.3                            -0.6
# 2                               4.4                              28
# 3                                 *                               *
# 4                              -1.7                             6.6
# ..                              ...                             ...
# 156                               *                               *
# 157                               *                               *
# 158                               *                               *
# 159                               *                               *
# 160                               *                               *
#
#                CancerType Age-Adjusted Incidence Rate(†) - cases per 100,000  \
# 0    Non-Hodgkin Lymphoma                                                NaN
# 1    Non-Hodgkin Lymphoma                                                NaN
# 2    Non-Hodgkin Lymphoma                                                NaN
# 3    Non-Hodgkin Lymphoma                                                NaN
# 4    Non-Hodgkin Lymphoma                                                NaN
# ..                    ...                                                ...
# 156                Kidney                                                NaN
# 157                Kidney                                                NaN
# 158                Kidney                                                NaN
# 159                Kidney                                                NaN
# 160                Kidney                                                NaN
#
#     Recent 5-Year Trend (‡) in Incidence Rates  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 156                                        NaN
# 157                                        NaN
# 158                                        NaN
# 159                                        NaN
# 160                                        NaN
#
#     Age-Adjusted Incidence Rate - cases per 100,000
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 156                                              *
# 157                                              *
# 158                                              *
# 159                                              *
# 160                                              *
#
# [805 rows x 14 columns]

# %%
# Remove value of '3 or fewer in column 'Average Annual Count'

ga_cancer_clean = ga_cancer_df.drop(ga_cancer_df.loc[ga_cancer_df['Average Annual Count']=="3 or fewer"].index)
ga_cancer_clean
# Out:
#        County   FIPS Age-Adjusted Incidence Rate(â€ ) - cases per 100,000  \
# 0     Georgia  13000                                               18.2
# 1          US      0                                               19.3
# 2      Gilmer  13123                                               29.3
# 3       Towns  13281                                               29.2
# 4     Pickens  13227                                               27.4
# ..        ...    ...                                                ...
# 58   Spalding  13255                                                NaN
# 59     Camden  13039                                                NaN
# 60  Dougherty  13095                                                NaN
# 61   Colquitt  13071                                                NaN
# 62  Habersham  13137                                                NaN
#
#    Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                           17.8                          18.6
# 1                           19.2                          19.3
# 2                           22.1                          38.2
# 3                           15.6                          49.9
# 4                           20.4                          36.1
# ..                           ...                           ...
# 58                          13.3                          22.3
# 59                          12.3                          23.8
# 60                          13.8                          21.5
# 61                          12.5                          23.3
# 62                          12.5                            23
#
#    Average Annual Count Recent Trend  \
# 0               1911.00       stable
# 1              70661.00      falling
# 2                 13.00       rising
# 3                  5.00            *
# 4                 12.00       stable
# ..                  ...          ...
# 58                13.00       stable
# 59                 8.00       stable
# 60                18.00       stable
# 61                 9.00       rising
# 62                 9.00       stable
#
#    Recent 5-Year Trend (â€¡) in Incidence Rates  \
# 0                                           0.3
# 1                                          -1.5
# 2                                          15.6
# 3                                             *
# 4                                           2.4
# ..                                          ...
# 58                                          3.6
# 59                                          2.5
# 60                                          1.3
# 61                                          3.5
# 62                                          1.4
#
#    Lower 95% Confidence Interval.1 Upper 95% Confidence Interval.1  \
# 0                             -0.1                             0.7
# 1                             -2.3                            -0.6
# 2                              4.4                              28
# 3                                *                               *
# 4                             -1.7                             6.6
# ..                             ...                             ...
# 58                            -0.3                             7.7
# 59                            -2.9                             8.2
# 60                            -1.1                             3.7
# 61                             0.1                               7
# 62                            -2.1                             5.1
#
#               CancerType Age-Adjusted Incidence Rate(†) - cases per 100,000  \
# 0   Non-Hodgkin Lymphoma                                                NaN
# 1   Non-Hodgkin Lymphoma                                                NaN
# 2   Non-Hodgkin Lymphoma                                                NaN
# 3   Non-Hodgkin Lymphoma                                                NaN
# 4   Non-Hodgkin Lymphoma                                                NaN
# ..                   ...                                                ...
# 58                Kidney                                                NaN
# 59                Kidney                                                NaN
# 60                Kidney                                                NaN
# 61                Kidney                                                NaN
# 62                Kidney                                                NaN
#
#    Recent 5-Year Trend (‡) in Incidence Rates  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 58                                        NaN
# 59                                        NaN
# 60                                        NaN
# 61                                        NaN
# 62                                        NaN
#
#    Age-Adjusted Incidence Rate - cases per 100,000
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 58                                            17.3
# 59                                            17.3
# 60                                            17.3
# 61                                            17.3
# 62                                            17.1
#
# [315 rows x 14 columns]

# %%
# Remove values 
ga_cancer_clean1 = ga_cancer_clean.drop(columns=['Age-Adjusted Incidence Rate(†) - cases per 100,000', 
                                                'Recent 5-Year Trend (‡) in Incidence Rates',
                                                'Age-Adjusted Incidence Rate - cases per 100,000'],axis=1)
ga_cancer_clean1

# Remove rows of 'Georgia' & 'US' under County column

ga_cancer_clean2 = ga_cancer_clean1.drop(ga_cancer_clean1[ga_cancer_clean1.County.isin(["Georgia", "US"])].index)
ga_cancer_clean2.reset_index()
ga_cancer_clean2
# Out:
#        County   FIPS Age-Adjusted Incidence Rate(â€ ) - cases per 100,000  \
# 2      Gilmer  13123                                               29.3
# 3       Towns  13281                                               29.2
# 4     Pickens  13227                                               27.4
# 5       Union  13291                                                 26
# 6     Lumpkin  13187                                               25.8
# ..        ...    ...                                                ...
# 58   Spalding  13255                                                NaN
# 59     Camden  13039                                                NaN
# 60  Dougherty  13095                                                NaN
# 61   Colquitt  13071                                                NaN
# 62  Habersham  13137                                                NaN
#
#    Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 2                           22.1                          38.2
# 3                           15.6                          49.9
# 4                           20.4                          36.1
# 5                           18.5                          36.2
# 6                           18.8                          34.7
# ..                           ...                           ...
# 58                          13.3                          22.3
# 59                          12.3                          23.8
# 60                          13.8                          21.5
# 61                          12.5                          23.3
# 62                          12.5                            23
#
#    Average Annual Count Recent Trend  \
# 2                 13.00       rising
# 3                  5.00            *
# 4                 12.00       stable
# 5                 11.00       stable
# 6                 10.00       stable
# ..                  ...          ...
# 58                13.00       stable
# 59                 8.00       stable
# 60                18.00       stable
# 61                 9.00       rising
# 62                 9.00       stable
#
#    Recent 5-Year Trend (â€¡) in Incidence Rates  \
# 2                                          15.6
# 3                                             *
# 4                                           2.4
# 5                                           0.8
# 6                                           4.2
# ..                                          ...
# 58                                          3.6
# 59                                          2.5
# 60                                          1.3
# 61                                          3.5
# 62                                          1.4
#
#    Lower 95% Confidence Interval.1 Upper 95% Confidence Interval.1  \
# 2                              4.4                              28
# 3                                *                               *
# 4                             -1.7                             6.6
# 5                             -3.2                             5.1
# 6                             -0.4                               9
# ..                             ...                             ...
# 58                            -0.3                             7.7
# 59                            -2.9                             8.2
# 60                            -1.1                             3.7
# 61                             0.1                               7
# 62                            -2.1                             5.1
#
#               CancerType
# 2   Non-Hodgkin Lymphoma
# 3   Non-Hodgkin Lymphoma
# 4   Non-Hodgkin Lymphoma
# 5   Non-Hodgkin Lymphoma
# 6   Non-Hodgkin Lymphoma
# ..                   ...
# 58                Kidney
# 59                Kidney
# 60                Kidney
# 61                Kidney
# 62                Kidney
#
# [305 rows x 11 columns]

# %%
#ga_cancer_clean.to_numeric(ga_cancer_clean['Average Annual Count'],erros='coerce')

ga_cancer_clean2['Average Annual Count'] = ga_cancer_clean2['Average Annual Count'].astype(float)
print(ga_cancer_clean2.dtypes)
# Out:
# County                                                   object
#  FIPS                                                     int64
# Age-Adjusted Incidence Rate(â€ ) - cases per 100,000     object
# Lower 95% Confidence Interval                            object
# Upper 95% Confidence Interval                            object
# Average Annual Count                                    float64
# Recent Trend                                             object
# Recent 5-Year Trend (â€¡) in Incidence Rates             object
# Lower 95% Confidence Interval.1                          object
# Upper 95% Confidence Interval.1                          object
# CancerType                                               object
# dtype: object
# C:\Users\Stephanie\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a bar chart for GA stats by Cancer Type

ga_cancer_type = ga_cancer_clean2.groupby('CancerType')

ga_cancer_sum = ga_cancer_type['Average Annual Count'].sum()

ga_cancer_bar = ga_cancer_sum.plot(kind='bar', colormap='summer')

ga_cancer_bar.set_title("GA Cancer Type Stats")
ga_cancer_bar.set_xlabel("Cancer Type")
ga_cancer_bar.set_ylabel("Sum of Cancer Type")

plt.savefig("../GA_Data/fig1")
plt.show()

# %%
ga_cancer_type = ga_cancer_clean2.groupby('CancerType')
ga_cancer_type_sum = ga_cancer_type['Average Annual Count'].sum()
ga_cancer_type_sum.head()
# Out:
# CancerType
# Kidney                   724.0
# Leukemia                 913.0
# Liver                    796.0
# Lung & Bronchus         1722.0
# Non-Hodgkin Lymphoma    1431.0
# Name: Average Annual Count, dtype: float64

# %%
# Create a pie chart to show GA stats by Cancer Type

ga_cancer_type = ga_cancer_clean2.groupby('CancerType')

ga_cancer_sum = ga_cancer_type['Average Annual Count'].sum()

cancer_type = list(ga_cancer_sum.index.values)

plt.title("GA Cancer Type Stats")

plt.axis("equal")

plt.pie(ga_cancer_sum, labels=cancer_type, colors = ['#FF99CC', '#99CCFF', '#FF9900','#FF8080','#33CCCC'], 
        autopct='%1.1f%%', startangle=60)

plt.savefig("../GA_Data/fig2")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ga_cancer_clean2
# Out:
#        County   FIPS Age-Adjusted Incidence Rate(â€ ) - cases per 100,000  \
# 2      Gilmer  13123                                               29.3
# 3       Towns  13281                                               29.2
# 4     Pickens  13227                                               27.4
# 5       Union  13291                                                 26
# 6     Lumpkin  13187                                               25.8
# ..        ...    ...                                                ...
# 58   Spalding  13255                                                NaN
# 59     Camden  13039                                                NaN
# 60  Dougherty  13095                                                NaN
# 61   Colquitt  13071                                                NaN
# 62  Habersham  13137                                                NaN
#
#    Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 2                           22.1                          38.2
# 3                           15.6                          49.9
# 4                           20.4                          36.1
# 5                           18.5                          36.2
# 6                           18.8                          34.7
# ..                           ...                           ...
# 58                          13.3                          22.3
# 59                          12.3                          23.8
# 60                          13.8                          21.5
# 61                          12.5                          23.3
# 62                          12.5                            23
#
#     Average Annual Count Recent Trend  \
# 2                   13.0       rising
# 3                    5.0            *
# 4                   12.0       stable
# 5                   11.0       stable
# 6                   10.0       stable
# ..                   ...          ...
# 58                  13.0       stable
# 59                   8.0       stable
# 60                  18.0       stable
# 61                   9.0       rising
# 62                   9.0       stable
#
#    Recent 5-Year Trend (â€¡) in Incidence Rates  \
# 2                                          15.6
# 3                                             *
# 4                                           2.4
# 5                                           0.8
# 6                                           4.2
# ..                                          ...
# 58                                          3.6
# 59                                          2.5
# 60                                          1.3
# 61                                          3.5
# 62                                          1.4
#
#    Lower 95% Confidence Interval.1 Upper 95% Confidence Interval.1  \
# 2                              4.4                              28
# 3                                *                               *
# 4                             -1.7                             6.6
# 5                             -3.2                             5.1
# 6                             -0.4                               9
# ..                             ...                             ...
# 58                            -0.3                             7.7
# 59                            -2.9                             8.2
# 60                            -1.1                             3.7
# 61                             0.1                               7
# 62                            -2.1                             5.1
#
#               CancerType
# 2   Non-Hodgkin Lymphoma
# 3   Non-Hodgkin Lymphoma
# 4   Non-Hodgkin Lymphoma
# 5   Non-Hodgkin Lymphoma
# 6   Non-Hodgkin Lymphoma
# ..                   ...
# 58                Kidney
# 59                Kidney
# 60                Kidney
# 61                Kidney
# 62                Kidney
#
# [305 rows x 11 columns]

# %%
# Import Georgia Landfill csv file from GitHub

url = "https://raw.githubusercontent.com/LCHoffman/Project_1/Lindsey/Georgia_trash.csv"
ga_landfill_df = pd.read_csv(url, error_bad_lines=False)
ga_landfill_df
# Out:
#     Unnamed: 0                                      Landfill Name State  \
# 0          556  Advanced Disposal Services Evergreen Landfill,...    GA
# 1          557                      Athens-Clarke County Landfill    GA
# 2          558                       Atkinson County - SR 50 MSWL    GA
# 3          559               Baker Place Road Landfill (Ph 1 & 2)    GA
# 4          560                                Bartow County MSWLF    GA
# ..         ...                                                ...   ...
# 61         625                                Turkey Run Landfill    GA
# 62         628                           Walker Mountain Landfill    GA
# 63         629                                      Watts Road LF    GA
# 64         630                     WI Taylor County Disposal, LLC    GA
# 65         632                           Wolf Creek Landfill, LLC    GA
#
#         County
# 0      Lowndes
# 1       Clarke
# 2     Atkinson
# 3     Columbia
# 4       Bartow
# ..         ...
# 61  Meriwether
# 62       Floyd
# 63      Fulton
# 64      Taylor
# 65      Twiggs
#
# [66 rows x 4 columns]

# %%
# Merge GA Cancer dataframe and GA Landfill dataframe

ga_data_merged1 = pd.merge(ga_cancer_clean2, ga_landfill_df, how='inner', on='County')
ga_data_merged1
# Out:
#          County   FIPS Age-Adjusted Incidence Rate(â€ ) - cases per 100,000  \
# 0        Newton  13217                                               22.2
# 1        Newton  13217                                                NaN
# 2        Newton  13217                                                NaN
# 3        Newton  13217                                                NaN
# 4        Bartow  13015                                               21.7
# ..          ...    ...                                                ...
# 174       Butts  13035                                                NaN
# 175       Butts  13035                                                NaN
# 176  Meriwether  13199                                                NaN
# 177   Jefferson  13163                                                NaN
# 178       Crisp  13081                                                NaN
#
#     Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                            18.3                          26.7
# 1                             7.3                          12.8
# 2                            16.3                          24.6
# 3                            17.6                          25.8
# 4                            17.8                          26.1
# ..                            ...                           ...
# 174                          13.2                          30.4
# 175                          13.4                            29
# 176                            12                          28.7
# 177                          14.4                          35.3
# 178                          13.4                            30
#
#      Average Annual Count Recent Trend  \
# 0                    24.0       stable
# 1                    11.0            *
# 2                    20.0       stable
# 3                    23.0       rising
# 4                    23.0       stable
# ..                    ...          ...
# 174                   5.0       stable
# 175                   6.0            *
# 176                   5.0       stable
# 177                   5.0            *
# 178                   6.0       stable
#
#     Recent 5-Year Trend (â€¡) in Incidence Rates  \
# 0                                              0
# 1                                            NaN
# 2                                            NaN
# 3                                            3.3
# 4                                           -0.3
# ..                                           ...
# 174                                          NaN
# 175                                            *
# 176                                          NaN
# 177                                            *
# 178                                          1.3
#
#     Lower 95% Confidence Interval.1 Upper 95% Confidence Interval.1  \
# 0                              -2.6                             2.7
# 1                                 *                               *
# 2                              -0.5                             7.7
# 3                               1.2                             5.4
# 4                              -3.3                             2.8
# ..                              ...                             ...
# 174                            -1.6                             9.2
# 175                               *                               *
# 176                            -2.1                             8.8
# 177                               *                               *
# 178                            -3.1                               6
#
#                CancerType  Unnamed: 0                 Landfill Name State
# 0    Non-Hodgkin Lymphoma         608        Newton County Landfill    GA
# 1                   Liver         608        Newton County Landfill    GA
# 2                Leukemia         608        Newton County Landfill    GA
# 3                  Kidney         608        Newton County Landfill    GA
# 4    Non-Hodgkin Lymphoma         560           Bartow County MSWLF    GA
# ..                    ...         ...                           ...   ...
# 174              Leukemia         613           Pine Ridge Landfill    GA
# 175                Kidney         613           Pine Ridge Landfill    GA
# 176              Leukemia         625           Turkey Run Landfill    GA
# 177                Kidney         599  Jefferson County CR-138 MSWL    GA
# 178                Kidney         580         Crisp County Landfill    GA
#
# [179 rows x 14 columns]

# %%
# Create a bar chart for Total number of Landfills for each county

ga_county_data = ga_data_merged1.groupby('County')
ga_landfill_count = ga_county_data['County'].count()

x_axis = np.arange(0, len(ga_county_data))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(18,5))
plt.xlim(-1.5, len(x_axis))
plt.ylim(0, max(ga_landfill_count)+2)

plt.xlabel("County")
plt.ylabel("Total Landfill")

plt.title("GA County vs Landfill")
plt.bar(x_axis, ga_landfill_count, facecolor="red", alpha=0.5, align="center", width=0.5)
plt.xticks(tick_locations, list(ga_landfill_count.index), rotation="vertical")

plt.tight_layout()
plt.savefig('../GA_Data/fig3')
plt.show()

# %%
ga_data_merged1
# Out:
#          County   FIPS Age-Adjusted Incidence Rate(â€ ) - cases per 100,000  \
# 0        Newton  13217                                               22.2
# 1        Newton  13217                                                NaN
# 2        Newton  13217                                                NaN
# 3        Newton  13217                                                NaN
# 4        Bartow  13015                                               21.7
# ..          ...    ...                                                ...
# 174       Butts  13035                                                NaN
# 175       Butts  13035                                                NaN
# 176  Meriwether  13199                                                NaN
# 177   Jefferson  13163                                                NaN
# 178       Crisp  13081                                                NaN
#
#     Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                            18.3                          26.7
# 1                             7.3                          12.8
# 2                            16.3                          24.6
# 3                            17.6                          25.8
# 4                            17.8                          26.1
# ..                            ...                           ...
# 174                          13.2                          30.4
# 175                          13.4                            29
# 176                            12                          28.7
# 177                          14.4                          35.3
# 178                          13.4                            30
#
#      Average Annual Count Recent Trend  \
# 0                    24.0       stable
# 1                    11.0            *
# 2                    20.0       stable
# 3                    23.0       rising
# 4                    23.0       stable
# ..                    ...          ...
# 174                   5.0       stable
# 175                   6.0            *
# 176                   5.0       stable
# 177                   5.0            *
# 178                   6.0       stable
#
#     Recent 5-Year Trend (â€¡) in Incidence Rates  \
# 0                                              0
# 1                                            NaN
# 2                                            NaN
# 3                                            3.3
# 4                                           -0.3
# ..                                           ...
# 174                                          NaN
# 175                                            *
# 176                                          NaN
# 177                                            *
# 178                                          1.3
#
#     Lower 95% Confidence Interval.1 Upper 95% Confidence Interval.1  \
# 0                              -2.6                             2.7
# 1                                 *                               *
# 2                              -0.5                             7.7
# 3                               1.2                             5.4
# 4                              -3.3                             2.8
# ..                              ...                             ...
# 174                            -1.6                             9.2
# 175                               *                               *
# 176                            -2.1                             8.8
# 177                               *                               *
# 178                            -3.1                               6
#
#                CancerType  Unnamed: 0                 Landfill Name State
# 0    Non-Hodgkin Lymphoma         608        Newton County Landfill    GA
# 1                   Liver         608        Newton County Landfill    GA
# 2                Leukemia         608        Newton County Landfill    GA
# 3                  Kidney         608        Newton County Landfill    GA
# 4    Non-Hodgkin Lymphoma         560           Bartow County MSWLF    GA
# ..                    ...         ...                           ...   ...
# 174              Leukemia         613           Pine Ridge Landfill    GA
# 175                Kidney         613           Pine Ridge Landfill    GA
# 176              Leukemia         625           Turkey Run Landfill    GA
# 177                Kidney         599  Jefferson County CR-138 MSWL    GA
# 178                Kidney         580         Crisp County Landfill    GA
#
# [179 rows x 14 columns]

# %%
# Create Line chart for Total count of Lung Cancer in each county

ga_county_data = ga_data_merged1.groupby('County')

ga_cancer_sum = ga_county_data['Average Annual Count'].sum()
ga_cancer_sum

x_axis = np.arange(0, len(ga_county_data))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(18,5))
plt.xlim(-0.5, len(x_axis))
plt.ylim(0, max(ga_cancer_sum)+100)

plt.xlabel("County")
plt.ylabel("Total Count of Cancer")

plt.title("GA County vs Cancer Counts")
plt.bar(x_axis, ga_cancer_sum, facecolor="deepskyblue", align="center", width=0.5)
plt.xticks(tick_locations, list(ga_cancer_sum.index), rotation="vertical")

plt.tight_layout()
plt.savefig('../GA_Data/fig4')
plt.show()

# %%
ga_data_me

# %%
# Import Landfill csv file for GA Latitude & Longitude data from GitHub

url = "https://raw.githubusercontent.com/LCHoffman/Project_1/Lindsey/landfilldata.csv"
landfill_df = pd.read_csv(url, error_bad_lines=False)
landfill_df
# Out:
#       Landfill ID                     Landfill Name State  \
# 0            1994       Anchorage Regional Landfill    AK
# 1           11941         Capitol Disposal Landfill    AK
# 2           12216  Central Peninsula Landfill (CPL)    AK
# 3           10960    Kodiak Island Borough Landfill    AK
# 4           11020            Merrill Field Landfill    AK
# ...           ...                               ...   ...
# 2624        20722     Campbell County Landfill No.2    WY
# 2625        11100                   Casper Balefill    WY
# 2626         2196                 Cheyenne Landfill    WY
# 2627        21136       Eastern Laramie County SWDD    WY
# 2628        11140        Sheridan Existing Landfill    WY
#
#                     Physical Address         City           County Zip Code  \
# 0     15500 E. Eagle River Loop Road  Eagle River        Anchorage    99577
# 1                5600 Tonsgard Court       Juneau           Juneau    99801
# 2             46915 Sterling Highway     Soldotna  Kenai Peninsula    99669
# 3             1203 Monashka Bay Road       Kodiak    Kodiak Island    99615
# 4            800 Merrill Field Drive    Anchorage        Anchorage    99501
# ...                              ...          ...              ...      ...
# 2624        909 Westover County Road     Gillette         Campbell    82718
# 2625            1886 N. Station Road   Evansville          Natrona    82636
# 2626            1461 Happy Jack Road     Cheyenne          Laramie    82009
# 2627                     4990 CR 216        Burns          Laramie    82053
# 2628              83 East Ridge Road     Sheridan         Sheridan    82801
#
#        Latitude   Longitude Ownership Type  \
# 0     61.293281 -149.602138         Public
# 1     58.352800 -134.494700        Private
# 2     60.447140 -151.103690         Public
# 3     57.808740 -152.407610         Public
# 4     61.212660 -149.840120         Public
# ...         ...         ...            ...
# 2624  44.281000 -105.512000         Public
# 2625  42.873192 -106.283097         Public
# 2626  41.135000 -105.005000         Public
# 2627  41.230852 -104.336488         Public
# 2628  44.804335 -106.923406         Public
#
#                          Landfill Owner Organization(s)  Year Landfill Opened  \
# 0                         Municipality of Anchorage, AK                1987.0
# 1                                Waste Management, Inc.                1965.0
# 2                           Kenai Peninsula Borough, AK                1969.0
# 3                             Kodiak Island Borough, AK                   NaN
# 4                         Municipality of Anchorage, AK                1960.0
# ...                                                 ...                   ...
# 2624                                Campbell County, WY                1987.0
# 2625                                 City of Casper, WY                1966.0
# 2626                               City of Cheyenne, WY                1966.0
# 2627  Eastern Laramie County Solid Waste Disposal Di...                1981.0
# 2628                               City of Sheridan, WY                1984.0
#
#      Current Landfill Status
# 0                       Open
# 1                       Open
# 2                       Open
# 3                     Closed
# 4                     Closed
# ...                      ...
# 2624                    Open
# 2625                    Open
# 2626                    Open
# 2627                    Open
# 2628                    Open
#
# [2629 rows x 13 columns]

# %%
# Merge Landfill dataframe and GA Landfill dataframe

ga_landfill_data_merged2 = pd.merge(ga_landfill_df, landfill_df, how='inner', on='Landfill Name')
ga_landfill_data_merged2
# Out:
#     Unnamed: 0                                      Landfill Name State_x  \
# 0          556  Advanced Disposal Services Evergreen Landfill,...      GA
# 1          557                      Athens-Clarke County Landfill      GA
# 2          558                       Atkinson County - SR 50 MSWL      GA
# 3          559               Baker Place Road Landfill (Ph 1 & 2)      GA
# 4          560                                Bartow County MSWLF      GA
# ..         ...                                                ...     ...
# 64         625                                Turkey Run Landfill      GA
# 65         628                           Walker Mountain Landfill      GA
# 66         629                                      Watts Road LF      GA
# 67         630                     WI Taylor County Disposal, LLC      GA
# 68         632                           Wolf Creek Landfill, LLC      GA
#
#       County_x  Landfill ID State_y  \
# 0      Lowndes          458      GA
# 1       Clarke          445      GA
# 2     Atkinson        10401      GA
# 3     Columbia          447      GA
# 4       Bartow         1985      GA
# ..         ...          ...     ...
# 64  Meriwether        20699      GA
# 65       Floyd         1986      GA
# 66      Fulton          465      GA
# 67      Taylor          461      GA
# 68      Twiggs        10404      GA
#
#                                      Physical Address          City  \
# 0                              2995 Wetherington Lane      Valdosta
# 1                                 5700 Lexington Road   Winterville
# 2                               64 Author Davis Drive  Willacoochee
# 3                                   468 Chamblin Road     Grovetown
# 4    40 Allatoona Dam Road\nbetween Hwy 41 & S.R. 293  Cartersville
# ..                                                ...           ...
# 64                                 7144 Lone Oak Road   Hogansville
# 65                           433 Walker Mountain Road          Rome
# 66                                 1144 Field Road NW       Atlanta
# 67                                    33 Stewart Road          Mauk
# 68  911 Landfill Road\noff Hwy 80 (Jeffersonville ...    Dry Branch
#
#       County_y Zip Code   Latitude  Longitude Ownership Type  \
# 0      Lowndes    31601  30.808000 -83.362500        Private
# 1       Clarke    30683  33.929000 -83.262700         Public
# 2     Atkinson    31650  31.319415 -82.964286         Public
# 3     Columbia    30813  33.489158 -82.234624         Public
# 4       Bartow    30120  34.143800 -84.764800         Public
# ..         ...      ...        ...        ...            ...
# 64  Meriwether    30230  33.163696 -84.848925        Private
# 65       Floyd    30161  34.190000 -85.214799         Public
# 66      Fulton    30318  33.785600 -84.485800        Private
# 67      Taylor    31058  32.462263 -84.371526        Private
# 68      Twiggs    31020  32.770535 -83.437873        Private
#
#                        Landfill Owner Organization(s)  Year Landfill Opened  \
# 0                          Advanced Disposal Services                1992.0
# 1   Unified Government of Athens-Clarke County (AC...                1977.0
# 2                                 Atkinson County, GA                1997.0
# 3                                 Columbia County, GA                1982.0
# 4                                   Bartow County, GA                1979.0
# ..                                                ...                   ...
# 64                             Waste Management, Inc.                2010.0
# 65                        Floyd County, GA; Rome City                1998.0
# 66                            Republic Services, Inc.                1970.0
# 67                                   Waste Industries                1989.0
# 68                         Advanced Disposal Services                1992.0
#
#    Current Landfill Status
# 0                     Open
# 1                     Open
# 2                     Open
# 3                   Closed
# 4                     Open
# ..                     ...
# 64                    Open
# 65                    Open
# 66                  Closed
# 67                    Open
# 68                    Open
#
# [69 rows x 16 columns]

# %%
# Create new dataframe for GA Landfill with Latitude & Longitude info
ga_landfill_map_data = ga_landfill_data_merged2[['Landfill Name', 'Latitude', 'Longitude', 'Ownership Type',
                                                     'Current Landfill Status']]
ga_landfill_map_data
# Out:
#                                         Landfill Name   Latitude  Longitude  \
# 0   Advanced Disposal Services Evergreen Landfill,...  30.808000 -83.362500
# 1                       Athens-Clarke County Landfill  33.929000 -83.262700
# 2                        Atkinson County - SR 50 MSWL  31.319415 -82.964286
# 3                Baker Place Road Landfill (Ph 1 & 2)  33.489158 -82.234624
# 4                                 Bartow County MSWLF  34.143800 -84.764800
# ..                                                ...        ...        ...
# 64                                Turkey Run Landfill  33.163696 -84.848925
# 65                           Walker Mountain Landfill  34.190000 -85.214799
# 66                                      Watts Road LF  33.785600 -84.485800
# 67                     WI Taylor County Disposal, LLC  32.462263 -84.371526
# 68                           Wolf Creek Landfill, LLC  32.770535 -83.437873
#
#    Ownership Type Current Landfill Status
# 0         Private                    Open
# 1          Public                    Open
# 2          Public                    Open
# 3          Public                  Closed
# 4          Public                    Open
# ..            ...                     ...
# 64        Private                    Open
# 65         Public                    Open
# 66        Private                  Closed
# 67        Private                    Open
# 68        Private                    Open
#
# [69 rows x 5 columns]

# %%
! pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\stephanie\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\stephanie\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
# Create a map for GA Landfill

gmaps.configure(api_key=g_map_key)
ga_landfill_name = ga_landfill_map_data["Landfill Name"].tolist()
ga_landfill_status = ga_landfill_map_data["Current Landfill Status"].tolist()
marker_locations = ga_landfill_map_data[["Latitude", "Longitude"]]

fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations,
                            info_box_content=[f"Landfill Name: {name}" for name in ga_landfill_name])
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
